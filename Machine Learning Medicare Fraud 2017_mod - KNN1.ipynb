# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook, tqdm

# %%
new_main_2017 = pd.read_csv('data/ml_2017.csv', low_memory=False)
print("The data has a size of {}".format(new_main_2017.shape))
# Out:
# The data has a size of (904999, 32)

# %%
new_main_2017.head(1)
# Out:
#    Unnamed: 0         npi specialty_description nppes_provider_state  \
# 0           0  1023417649     Internal Medicine                   PA
#
#    t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# 0                     512.29                       14               2.7
#
#    %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  ...  \
# 0                0.0              0.0               0.0  ...
#
#    antipsych_cost_per_claim_ge65  antipsych_claim_per_bene_ge65  \
# 0                            0.0                            0.0
#
#    total_30_day_fill_count  total_day_supply  total_30_day_fill_count_ge65  \
# 0                    605.0             13547                         533.9
#
#    total_day_supply_ge65  opioid_day_supply  opioid_prescriber_rate  \
# 0                12009.0                0.0                     0.0
#
#    is_excluded       year
# 0            0  2017-2018
#
# [1 rows x 32 columns]

# %%
new_main_2017.drop(['Unnamed: 0'], axis=1, inplace = True)

# %%
new_main_2017.drop(['npi', 'specialty_description','nppes_provider_state','year'], axis=1, inplace = True)

# %%
new_main_2017.head(1)
# Out:
#    t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# 0                     512.29                       14               2.7
#
#    %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# 0                0.0              0.0               0.0             0.0
#
#    t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# 0            6966.0                 5285.0                  269.0  ...
#
#    antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# 0                      116.0                            0.0
#
#    antipsych_claim_per_bene_ge65  total_30_day_fill_count  total_day_supply  \
# 0                            0.0                    605.0             13547
#
#    total_30_day_fill_count_ge65  total_day_supply_ge65  opioid_day_supply  \
# 0                         533.9                12009.0                0.0
#
#    opioid_prescriber_rate  is_excluded
# 0                     0.0            0
#
# [1 rows x 27 columns]

# %%
len(new_main_2017[new_main_2017['is_excluded'] == 1])
# Out:
# 101

# %%
dropIndex = new_main_2017[new_main_2017['is_excluded'] == 1].index

# %%
len(new_main_2017[new_main_2017['is_excluded'] == 0])
# Out:
# 904898

# %%
only_excluded = new_main_2017[new_main_2017['is_excluded'] == 1]
new_main_2017.drop(dropIndex, inplace = True)
new_main_2017 = new_main_2017.sample(frac=1)
random_sample = new_main_2017.iloc[0:85000]
new_df = pd.concat([only_excluded, random_sample])
new_main_2017 = new_main_2017.drop(new_main_2017.iloc[0:85000].index, axis = 0)
new_df = new_df.sample(frac=1)
#part_d_df.iloc[0:85000].index

# %%
#new_df.drop(['Unnamed: 0'], axis=1, inplace = True)
new_df.head()
# Out:
#         t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# 867197                     246.47                        8               2.0
# 276269                     942.23                        6               2.0
# 801911                     928.64                       29              10.6
# 881748                    2144.69                       97              13.5
# 723612                    3871.16                       19               7.1
#
#         %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# 867197                0.0              0.0               0.0             0.0
# 276269               10.0             32.0              10.0            32.0
# 801911                0.0              0.0               0.0             0.0
# 881748               20.0             66.0              20.0            66.0
# 723612               30.0             85.0              30.0            85.0
#
#         t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# 867197            2127.0                 2134.0                  185.0  ...
# 276269            7015.0                    0.0                    0.0  ...
# 801911            3576.0                    0.0                    0.0  ...
# 881748            7859.0                 6975.0                 1298.0  ...
# 723612           11160.0                12270.0                  697.0  ...
#
#         antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# 867197                      115.0                            0.0
# 276269                      177.0                            0.0
# 801911                      120.0                            0.0
# 881748                      191.0                        10831.0
# 723612                      148.0                            0.0
#
#         antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# 867197                            0.0                    533.4
# 276269                            0.0                    247.0
# 801911                            0.0                   1229.3
# 881748                            0.0                  10545.3
# 723612                            0.0                   1668.1
#
#         total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# 867197             11055                         459.4                 9284.0
# 276269              4819                           0.0                    0.0
# 801911             23780                           0.0                    0.0
# 881748            302069                        9385.7               270607.0
# 723612             45290                        1209.8                32942.0
#
#         opioid_day_supply  opioid_prescriber_rate  is_excluded
# 867197              209.0                    3.76            0
# 276269                0.0                    0.00            0
# 801911             1985.0                   12.72            0
# 881748             4064.0                    3.61            0
# 723612                0.0                    0.00            0
#
# [5 rows x 27 columns]

# %%
new_main_2017.describe()
# Out:
#        t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# count               8.198980e+05            819898.000000     819898.000000
# mean                2.208844e+03                25.550107          6.393100
# std                 5.388622e+03                40.569592          7.116524
# min                 0.000000e+00                 0.000000          0.000000
# 25%                 1.671100e+02                 2.000000          1.900000
# 50%                 6.747150e+02                 7.000000          3.600000
# 75%                 2.371725e+03                29.000000          8.300000
# max                 1.017741e+06               394.000000        307.100000
#
#        %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# count      819898.000000    819898.000000     819898.000000   819898.000000
# mean           12.584395        38.954682         12.363013       38.896282
# std            16.526858        37.130189         15.888696       36.906382
# min             0.000000         0.000000          0.000000        0.000000
# 25%             0.000000         0.000000          0.000000        0.000000
# 50%            10.000000        42.000000         10.000000       43.000000
# 75%            20.000000        73.000000         20.000000       73.000000
# max           100.000000       100.000000        100.000000      100.000000
#
#        t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# count      8.198980e+05           8.198980e+05          819898.000000  ...
# mean       1.257547e+04           1.030496e+04             479.157409  ...
# std        5.528685e+04           3.688839e+04             685.640149  ...
# min        0.000000e+00           0.000000e+00               0.000000  ...
# 25%        2.352000e+03           1.398000e+03               0.000000  ...
# 50%        5.502000e+03           4.652000e+03             222.000000  ...
# 75%        9.336000e+03           7.997000e+03             653.000000  ...
# max        1.712797e+07           7.622389e+06           27000.000000  ...
#
#        antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# count              819898.000000                  819898.000000
# mean                   92.336221                    1386.847383
# std                    82.618756                    6996.215297
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.000000
# 50%                   113.000000                       0.000000
# 75%                   143.000000                       0.000000
# max                  3422.000000                  479253.000000
#
#        antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# count                  819898.000000            819898.000000
# mean                       28.154797              2508.802512
# std                       143.928144              5111.246715
# min                         0.000000                11.000000
# 25%                         0.000000               141.000000
# 50%                         0.000000               445.800000
# 75%                         0.000000              2267.700000
# max                      6007.000000            202437.100000
#
#        total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# count      8.198980e+05                 819898.000000           8.198980e+05
# mean       6.976203e+04                   2032.977247           5.684854e+04
# std        1.437445e+05                   4436.675680           1.251252e+05
# min        1.100000e+01                      0.000000           0.000000e+00
# 25%        2.166000e+03                     72.100000           9.720000e+02
# 50%        1.029100e+04                    298.700000           6.699000e+03
# 75%        6.287900e+04                   1611.200000           4.444100e+04
# max        3.679804e+06                 178412.300000           3.208984e+06
#
#        opioid_day_supply  opioid_prescriber_rate  is_excluded
# count      819898.000000           819898.000000     819898.0
# mean         1839.612658                8.757103          0.0
# std          8313.409819               18.383310          0.0
# min             0.000000                0.000000          0.0
# 25%             0.000000                0.000000          0.0
# 50%            46.000000                0.810000          0.0
# 75%           632.000000                8.440000          0.0
# max        615456.000000              909.000000          0.0
#
# [8 rows x 27 columns]

# %%
import math

# %%
from sklearn import decomposition
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, auc
from sklearn.utils import resample
from sklearn.preprocessing import label_binarize
from sklearn.svm import SVC
from scipy.stats import pointbiserialr

# %%
#part_d_excluded = new_df[new_df["is_excluded"]==1]

fudge = resample(only_excluded, replace=True, n_samples=1000000, random_state = 0)
#fudge.drop(['Unnamed: 0'], axis=1, inplace = True)
fudge.describe()
# Out:
#        t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# count             1000000.000000           1000000.000000    1000000.000000
# mean                 5194.967630                38.609067          9.485671
# std                 28249.745002                55.813583          9.620971
# min                    40.990000                 1.000000          0.000000
# 25%                   293.230000                 3.000000          2.200000
# 50%                  1206.820000                11.000000          5.800000
# 75%                  3338.240000                54.000000         13.800000
# max                286886.380000               299.000000         46.100000
#
#        %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# count     1000000.000000   1000000.000000    1000000.000000  1000000.000000
# mean           11.374050        36.234950         10.876360       36.026284
# std            14.980311        36.168503         12.989995       35.937057
# min             0.000000         0.000000          0.000000        0.000000
# 25%             0.000000         0.000000          0.000000        0.000000
# 50%            10.000000        43.000000         10.000000       43.000000
# 75%            20.000000        71.000000         20.000000       70.000000
# max           100.000000       100.000000         60.000000       98.000000
#
#        t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# count    1000000.000000         1000000.000000         1000000.000000  ...
# mean       10551.133795            8908.213605             751.031469  ...
# std        17528.724650           16454.262782             932.513383  ...
# min          294.000000               0.000000               0.000000  ...
# 25%         4406.000000            2876.000000               0.000000  ...
# 50%         7223.000000            5345.000000             378.000000  ...
# 75%        10419.000000            7982.000000            1163.000000  ...
# max       141957.000000          125896.000000            4355.000000  ...
#
#        antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# count             1000000.000000                 1000000.000000
# mean                   77.438471                    2743.050558
# std                    88.433065                    8561.702769
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.000000
# 50%                     0.000000                       0.000000
# 75%                   157.000000                     633.000000
# max                   322.000000                   50758.000000
#
#        antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# count                 1000000.000000           1000000.000000
# mean                       43.789287              3131.733322
# std                       158.750327              5513.810033
# min                         0.000000                13.000000
# 25%                         0.000000               109.000000
# 50%                         0.000000               632.600000
# 75%                         0.000000              3164.200000
# max                       803.000000             33073.000000
#
#        total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# count    1000000.000000                1000000.000000         1000000.000000
# mean       88423.346199                   2090.284659           59364.759391
# std       156739.468845                   4178.857341          118866.398677
# min          221.000000                      0.000000               0.000000
# 25%         2955.000000                     62.000000            1280.000000
# 50%        18369.000000                    368.400000           10843.000000
# 75%        90194.000000                   1882.600000           52000.000000
# max       934916.000000                  22770.800000          647623.000000
#
#        opioid_day_supply  opioid_prescriber_rate  is_excluded
# count     1000000.000000          1000000.000000    1000000.0
# mean         5985.222628                8.280612          1.0
# std         22597.822680               14.853448          0.0
# min             0.000000                0.000000          1.0
# 25%             0.000000                0.000000          1.0
# 50%             0.000000                0.000000          1.0
# 75%          3107.000000                7.590000          1.0
# max        213611.000000               68.220000          1.0
#
# [8 rows x 27 columns]

# %%
std = fudge.describe().loc["std"]
std = std[0:26]

# %%
rtstd = std.map(lambda x : math.sqrt(x)/2) #use half of square root of standard deviation as the range for gaussian normal
rtstd = rtstd.to_dict()

# %%
for key in rtstd:
    #fudge[key] = fudge[key].map(lambda x: (np.random.normal(x, rtstd[key])))
    fudge[key] = fudge[key].map(lambda x: (np.random.normal(x, 2)))
fudge = fudge[fudge>=0]
fudge.dropna(inplace = True)

# %%
rtstd
# Out:
# {'t_cost_per_claim_excluded': 84.03830228283725,
#  't_claim_count_schedule2': 3.735424432090368,
#  't_claim_per_bene': 1.5508844893809823,
#  '%b2bg_claim_count': 1.9352203219559672,
#  '%b2bg_drug_cost': 3.007012758064355,
#  '%b2t_claim_count': 1.802081760350314,
#  '%b2t_drug_cost': 2.99737621069871,
#  't_cost_per_claim': 66.19804500548426,
#  't_cost_per_claim_ge65': 64.13708518052151,
#  't_claim_per_bene_ge65': 15.268541048298102,
#  'mapd_cost_per_claim': 64.61408506431768,
#  'pdp_cost_per_claim': 67.25735816485223,
#  'lis_cost_per_claim': 68.22596052313033,
#  'nonlis_cost_per_claim': 62.07153722436618,
#  'opioid_cost_per_claim': 46.504668620058595,
#  'opioid_claim_per_bene': 8.847407251096762,
#  'antibiotic_cost_per_claim': 29.817508674809556,
#  'antibiotic_claim_per_bene': 4.701942818546453,
#  'antipsych_cost_per_claim_ge65': 46.26473486591827,
#  'antipsych_claim_per_bene_ge65': 6.299808071086247,
#  'total_30_day_fill_count': 37.12751686106159,
#  'total_day_supply': 197.95167898077315,
#  'total_30_day_fill_count_ge65': 32.32204101305794,
#  'total_day_supply_ge65': 172.3850331940279,
#  'opioid_day_supply': 75.1628609755071,
#  'opioid_prescriber_rate': 1.9270085656978702}

# %%
fudge.describe()
# Out:
#        t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# count              114642.000000            114642.000000     114642.000000
# mean                 3610.472500               121.672506         21.034079
# std                  3233.441929                76.064419         10.516700
# min                    38.644341                 0.005655          0.000770
# 25%                  1819.132624                62.315426         14.004560
# 50%                  2715.734636               117.515171         19.594949
# 75%                  4191.643218               151.954988         24.776768
# max                286888.027607               306.353687         53.017117
#
#        %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# count      114642.000000    114642.000000     114642.000000   114642.000000
# mean           17.610484        66.586843         17.618716       66.095176
# std             6.760838        12.691614          6.764236       12.706698
# min             0.003298         0.001281          0.000313        0.000970
# 25%            11.446890        63.815833         11.450223       63.401653
# 50%            18.950779        68.928930         18.955898       68.677478
# 75%            21.205270        73.448296         21.209024       72.860996
# max            64.712728       103.036229         66.203766      103.209662
#
#        t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# count     114642.000000          114642.000000          114642.000000  ...
# mean        8197.915398            7532.210710            2016.877904  ...
# std         5453.506404            4808.451502            1060.459798  ...
# min          368.558671             367.082011               0.005096  ...
# 25%         5312.934513            4753.827964            1418.398069  ...
# 50%         5956.733552            5687.835328            1767.796818  ...
# 75%        10246.499431            9553.779917            2606.546475  ...
# max       141955.913887          125896.167335            4362.317965  ...
#
#        antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# count              114642.000000                  114642.000000
# mean                  168.295160                    8516.228303
# std                    51.600347                   14315.317133
# min                     0.000088                       0.000165
# 25%                   157.496415                     754.145416
# 50%                   172.302015                    3287.719549
# 75%                   209.785061                    4982.199131
# max                   328.814016                   50760.914010
#
#        antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# count                  114642.000000            114642.000000
# mean                      248.568582             10424.205704
# std                       307.918437              8896.983964
# min                         0.000021                34.685759
# 25%                         1.153223              3232.330477
# 50%                         3.078488              9283.868648
# 75%                       623.210527             13861.501950
# max                       809.737570             33080.278594
#
#        total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# count     114642.000000                 114642.000000          114642.000000
# mean      293887.999466                   7247.809990          205029.987661
# std       252035.634080                   6933.347960          196504.030050
# min          230.724371                     12.779439             221.321506
# 25%        91530.036286                   2205.658796           63403.443958
# 50%       268680.440928                   5177.138560          147270.636325
# 75%       390052.071974                   9288.864247          270397.477594
# max       934923.144587                  22778.660835          647630.529589
#
#        opioid_day_supply  opioid_prescriber_rate  is_excluded
# count      114642.000000           114642.000000     114642.0
# mean        12122.104619                8.544021          1.0
# std         13912.851871                9.952649          0.0
# min             0.000054                0.000360          1.0
# 25%          4623.870022                3.481585          1.0
# 50%         10184.173744                6.229456          1.0
# 75%         19232.288268                9.575703          1.0
# max        213616.522274               73.400518          1.0
#
# [8 rows x 27 columns]

# %%
only_excluded.describe()
# Out:
#        t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# count                 101.000000               101.000000        101.000000
# mean                 5221.393465                38.673267          9.499010
# std                 28518.834547                56.116684          9.667021
# min                    40.990000                 1.000000          0.000000
# 25%                   293.230000                 3.000000          2.200000
# 50%                  1206.820000                11.000000          5.800000
# 75%                  3338.240000                54.000000         13.800000
# max                286886.380000               299.000000         46.100000
#
#        %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# count         101.000000       101.000000        101.000000      101.000000
# mean           11.386139        36.306931         10.891089       36.099010
# std            15.035272        36.333935         13.045996       36.102771
# min             0.000000         0.000000          0.000000        0.000000
# 25%             0.000000         0.000000          0.000000        0.000000
# 50%            10.000000        43.000000         10.000000       43.000000
# 75%            20.000000        71.000000         20.000000       70.000000
# max           100.000000       100.000000         60.000000       98.000000
#
#        t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# count        101.000000             101.000000             101.000000  ...
# mean       10562.524752            8919.534653             751.980198  ...
# std        17653.641240           16564.118105             937.517232  ...
# min          294.000000               0.000000               0.000000  ...
# 25%         4406.000000            2876.000000               0.000000  ...
# 50%         7223.000000            5345.000000             378.000000  ...
# 75%        10419.000000            7982.000000            1163.000000  ...
# max       141957.000000          125896.000000            4355.000000  ...
#
#        antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# count                 101.000000                     101.000000
# mean                   77.495050                    2757.247525
# std                    88.851182                    8633.955942
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.000000
# 50%                     0.000000                       0.000000
# 75%                   157.000000                     633.000000
# max                   322.000000                   50758.000000
#
#        antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# count                     101.000000               101.000000
# mean                       44.079208              3136.292079
# std                       159.991417              5542.441612
# min                         0.000000                13.000000
# 25%                         0.000000               109.000000
# 50%                         0.000000               632.600000
# 75%                         0.000000              3164.200000
# max                       803.000000             33073.000000
#
#        total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# count        101.000000                    101.000000             101.000000
# mean       88552.960396                   2093.873267           59466.841584
# std       157554.695894                   4202.779267          119551.162208
# min          221.000000                      0.000000               0.000000
# 25%         2955.000000                     62.000000            1280.000000
# 50%        18369.000000                    368.400000           10843.000000
# 75%        90194.000000                   1882.600000           52000.000000
# max       934916.000000                  22770.800000          647623.000000
#
#        opioid_day_supply  opioid_prescriber_rate  is_excluded
# count         101.000000              101.000000        101.0
# mean         5972.128713                8.322871          1.0
# std         22570.729549               14.976968          0.0
# min             0.000000                0.000000          1.0
# 25%             0.000000                0.000000          1.0
# 50%             0.000000                0.000000          1.0
# 75%          3107.000000                7.590000          1.0
# max        213611.000000               68.220000          1.0
#
# [8 rows x 27 columns]

# %%
fudge.shape
# Out:
# (114642, 27)

# %%
fudge=fudge.sample(n=10000)
fudge.head()
# Out:
#         t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# 250232                2056.413425               138.963608         23.654731
# 235793                3759.887422               132.636833         22.891183
# 250232                2053.597079               133.870399         23.844083
# 147325                3003.540768               152.851507         27.888951
# 658804                4742.260083                41.486814         10.270545
#
#         %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# 250232          19.575521        67.726706         18.744813       67.908625
# 235793          20.506741        69.372531         19.959516       68.453592
# 250232          18.362334        67.289292         18.175312       67.497963
# 147325           9.112401        66.397500         11.863728       70.127789
# 658804          20.919985        65.677369         17.597252       64.045484
#
#         t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# 250232       5317.763274            4755.266391            2068.878298  ...
# 235793       5313.344976            5161.257292            2147.303118  ...
# 250232       5317.367937            4754.345867            2069.577299  ...
# 147325       5348.608032            4395.177404            2159.023758  ...
# 658804      17795.446793           15802.226036             887.922113  ...
#
#         antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# 250232                 155.069999                    4456.546055
# 235793                 164.622141                   23299.556571
# 250232                 155.125374                    4456.193639
# 147325                 213.581349                       1.051866
# 658804                 185.229377                   48020.660520
#
#         antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# 250232                     461.664780              9670.868783
# 235793                       0.429912             13859.976091
# 250232                     458.031139              9672.400180
# 147325                       2.480213             13377.078406
# 658804                     312.019073              1726.113894
#
#         total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# 250232     268681.362415                   7813.642808          219074.494932
# 235793     390050.916279                   5931.528235          171613.007103
# 250232     268680.973384                   7810.673957          219078.179395
# 147325     389318.953305                   9285.275187          270396.262967
# 658804      48999.870377                    949.696414           27246.070632
#
#         opioid_day_supply  opioid_prescriber_rate  is_excluded
# 250232       10875.251359                8.602871            1
# 235793       23967.078814                7.607205            1
# 250232       10878.094594               14.185368            1
# 147325       19230.139687                5.069689            1
# 658804        5326.707150               13.617654            1
#
# [5 rows x 27 columns]

# %%
ag_2017 = pd.concat([new_main_2017, fudge])
ag_2017.dropna(inplace=True)

# %%
ag_2017[ag_2017["is_excluded"]==1].shape
# Out:
# (10000, 27)

# %%
ag_2017.shape
# Out:
# (829898, 27)

# %%
#Classification Model Comparisons

def warn(*args, **kwargs):
    pass

import warnings
warnings.warn = warn

from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle

#from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
#from sklearn.svm import SVC
#from sklearn.gaussian_process import GaussianProcessClassifier
#from sklearn.gaussian_process.kernels import RBF
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
#from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import cross_validate, GridSearchCV, StratifiedKFold
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, auc, recall_score, precision_score, accuracy_score, f1_score

seed = 42

# %%
# Identifying the best model algorithm
#colors = ["#08306b", "#08519c", "#1361a9", "#4292c6", "#6baed6", 'rgb(76,000,153)', 'rgb(153,000,153)']

#names = ["GradientBoost", "ExtraTrees", "Random Forest", "Naive Bayes", "Nearest Neighbors", "AdaBoost"]

colors = ["#08306b"]
names = ["Nearest Neighbors"]

classifiers = [
            #GradientBoostingClassifier(n_estimators=50, random_state=seed),
             #ExtraTreesClassifier(n_estimators=25, random_state=seed),
             #RandomForestClassifier(n_estimators=25, random_state=seed),      
             #GaussianNB(),
            KNeighborsClassifier(n_neighbors=1)]
             #AdaBoostClassifier(n_estimators=25, random_state=seed)]

# %%
trace_dict = {'x_vals':[], 'y_vals':[], 'colors':[], 'names':[]}
                                                                                         
# iterate over classifiers
counter = 0
for color, name, clf in tqdm_notebook(zip(colors, names, classifiers), total=len(names)):
    X_train = ag_2017.drop(['is_excluded'], axis=1)
    y_train = ag_2017['is_excluded']
    X_test = new_df.drop(['is_excluded'], axis =1)
    y_test = new_df["is_excluded"]
    clf.fit(X_train, y_train)
    y_pred_prob = clf.predict_proba(X_test)
    cv_results = roc_auc_score(y_test, y_pred_prob[:,1])
    print('########################### \nFor {}'.format(name))
              
    trace_dict['x_vals'].append(counter)
    counter += 1
    print(cv_results)
    trace_dict['y_vals'].append(cv_results.mean())
    trace_dict['colors'].append(color)
    trace_dict['names'].append(name)
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# ###########################
# For Nearest Neighbors
# 0.8316655212580083
