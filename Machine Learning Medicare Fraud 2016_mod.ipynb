# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook, tqdm

# %%
new_main_2016 = pd.read_csv('data/ml_2016.csv', low_memory=False)
print("The data has a size of {}".format(new_main_2016.shape))
# Out:
# The data has a size of (880088, 32)

# %%
new_main_2016.head(1)
# Out:
#    Unnamed: 0         npi specialty_description nppes_provider_state  \
# 0           0  1558336487       Family Practice                   TN
#
#    t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# 0                    1728.07                       45              14.2
#
#    %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  ...  \
# 0               20.0             66.0              20.0  ...
#
#    antipsych_cost_per_claim_ge65  antipsych_claim_per_bene_ge65  \
# 0                            0.0                            0.0
#
#    total_30_day_fill_count  total_day_supply  total_30_day_fill_count_ge65  \
# 0                   2955.3             84653                        2059.5
#
#    total_day_supply_ge65  opioid_day_supply  opioid_prescriber_rate  \
# 0                59058.0             2397.0                    5.23
#
#    is_excluded       year
# 0            0  2016-2017
#
# [1 rows x 32 columns]

# %%
new_main_2016.drop(['Unnamed: 0'], axis=1, inplace = True)

# %%
new_main_2016.drop(['npi', 'specialty_description','nppes_provider_state','year'], axis=1, inplace = True)

# %%
new_main_2016.head(1)
# Out:
#    t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# 0                    1728.07                       45              14.2
#
#    %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# 0               20.0             66.0              20.0            66.0
#
#    t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# 0            8295.0                 7506.0                 1427.0  ...
#
#    antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# 0                      172.0                            0.0
#
#    antipsych_claim_per_bene_ge65  total_30_day_fill_count  total_day_supply  \
# 0                            0.0                   2955.3             84653
#
#    total_30_day_fill_count_ge65  total_day_supply_ge65  opioid_day_supply  \
# 0                        2059.5                59058.0             2397.0
#
#    opioid_prescriber_rate  is_excluded
# 0                    5.23            0
#
# [1 rows x 27 columns]

# %%
len(new_main_2016[new_main_2016['is_excluded'] == 1])
# Out:
# 151

# %%
dropIndex = new_main_2016[new_main_2016['is_excluded'] == 1].index

# %%
len(new_main_2016[new_main_2016['is_excluded'] == 0])
# Out:
# 879937

# %%
only_excluded = new_main_2016[new_main_2016['is_excluded'] == 1]
new_main_2016.drop(dropIndex, inplace = True)
new_main_2016 = new_main_2016.sample(frac=1)
random_sample = new_main_2016.iloc[0:175867]
new_df = pd.concat([only_excluded, random_sample])
new_main_2016 = new_main_2016.drop(new_main_2016.iloc[0:175867].index, axis = 0)
new_df = new_df.sample(frac=1)
#part_d_df.iloc[0:85000].index

# %%
#new_df.drop(['Unnamed: 0'], axis=1, inplace = True)
new_df.head()
# Out:
#         t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# 750419                     201.00                        1               0.0
# 861650                     646.67                       30              18.3
# 863119                      99.12                        4               1.4
# 471016                    2389.84                      104              12.7
# 168861                    1543.66                       71              11.1
#
#         %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# 750419                0.0              0.0               0.0             0.0
# 861650                0.0              0.0               0.0             0.0
# 863119                0.0              0.0               0.0             0.0
# 471016               20.0             76.0              20.0            76.0
# 168861               20.0             74.0              20.0            73.0
#
#         t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# 750419            9375.0                    0.0                    0.0  ...
# 861650            5255.0                 4352.0                 1949.0  ...
# 863119            1027.0                  912.0                  132.0  ...
# 471016            8569.0                 7557.0                 1154.0  ...
# 168861            7116.0                 6392.0                 1088.0  ...
#
#         antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# 750419                        0.0                            0.0
# 861650                      164.0                            0.0
# 863119                      103.0                            0.0
# 471016                      152.0                            0.0
# 168861                      152.0                         1636.0
#
#         antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# 750419                            0.0                    186.5
# 861650                            0.0                   2131.4
# 863119                            0.0                    171.0
# 471016                            0.0                   8415.5
# 168861                            0.0                   5744.7
#
#         total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# 750419              5474                           0.0                    0.0
# 861650             61773                        1718.4                49976.0
# 863119              1637                         103.0                 1034.0
# 471016            241813                        6349.4               183654.0
# 168861            168494                        4961.8               145636.0
#
#         opioid_day_supply  opioid_prescriber_rate  is_excluded
# 750419                0.0                    0.00            0
# 861650             1477.0                    3.65            0
# 863119               90.0                   21.76            0
# 471016             5354.0                    5.87            0
# 168861             4844.0                    6.00            0
#
# [5 rows x 27 columns]

# %%
new_main_2016.describe()
# Out:
#        t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# count              704070.000000            704070.000000     704070.000000
# mean                 2172.770650                26.660711          6.555050
# std                  4941.934537                42.312507          7.290439
# min                     0.000000                 0.000000          0.000000
# 25%                   181.600000                 2.000000          1.900000
# 50%                   755.515000                 8.000000          3.700000
# 75%                  2446.200000                30.000000          8.500000
# max                919663.700000               455.000000        287.700000
#
#        %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# count      704070.000000    704070.000000     704070.000000   704070.000000
# mean           13.221256        38.744723         12.959976       38.691906
# std            17.076233        37.002288         16.295430       36.773160
# min             0.000000         0.000000          0.000000        0.000000
# 25%             0.000000         0.000000          0.000000        0.000000
# 50%            10.000000        42.000000         10.000000       42.000000
# 75%            20.000000        73.000000         20.000000       73.000000
# max           100.000000       100.000000        100.000000      100.000000
#
#        t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# count      7.040700e+05           7.040700e+05          704070.000000  ...
# mean       1.204178e+04           9.887371e+03             494.343145  ...
# std        4.963795e+04           3.726739e+04             706.458448  ...
# min        0.000000e+00           0.000000e+00               0.000000  ...
# 25%        2.505000e+03           1.504000e+03               0.000000  ...
# 50%        5.468000e+03           4.672000e+03             226.000000  ...
# 75%        9.114000e+03           7.865000e+03             673.000000  ...
# max        1.216947e+07           6.460196e+06           20871.000000  ...
#
#        antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# count              704070.000000                  704070.000000
# mean                   92.620355                    1491.195255
# std                    83.466712                    6647.863076
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.000000
# 50%                   113.000000                       0.000000
# 75%                   144.000000                       0.000000
# max                  2880.000000                  395961.000000
#
#        antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# count                  704070.000000            704070.000000
# mean                       28.168415              2465.130413
# std                       144.625400              5042.492465
# min                         0.000000                11.000000
# 25%                         0.000000               137.500000
# 50%                         0.000000               435.000000
# 75%                         0.000000              2215.675000
# max                      5571.000000            324736.200000
#
#        total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# count      7.040700e+05                 704070.000000           7.040700e+05
# mean       6.851442e+04                   1984.392880           5.547745e+04
# std        1.414806e+05                   4360.087857           1.226778e+05
# min        1.100000e+01                      0.000000           0.000000e+00
# 25%        2.122000e+03                     70.000000           9.410000e+02
# 50%        1.003500e+04                    285.100000           6.427000e+03
# 75%        6.150275e+04                   1554.700000           4.289900e+04
# max        4.731349e+06                 270554.600000           3.925550e+06
#
#        opioid_day_supply  opioid_prescriber_rate  is_excluded
# count      704070.000000           704070.000000     704070.0
# mean         1957.376146                9.546794          0.0
# std          8310.403220               19.539138          0.0
# min             0.000000                0.000000          0.0
# 25%             0.000000                0.000000          0.0
# 50%            68.000000                1.410000          0.0
# 75%           726.000000                9.760000          0.0
# max        562886.000000              908.000000          0.0
#
# [8 rows x 27 columns]

# %%
import math

# %%
from sklearn import decomposition
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, auc
from sklearn.utils import resample
from sklearn.preprocessing import label_binarize
from sklearn.svm import SVC
from scipy.stats import pointbiserialr

# %%
#part_d_excluded = new_df[new_df["is_excluded"]==1]

fudge = resample(only_excluded, replace=True, n_samples=1000000, random_state = 0)
#fudge.drop(['Unnamed: 0'], axis=1, inplace = True)
fudge.describe()
# Out:
#        t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# count             1000000.000000           1000000.000000    1000000.000000
# mean                 2779.629688                35.975765         10.518284
# std                  3789.183011                53.286796          9.787844
# min                    19.460000                 1.000000          0.000000
# 25%                   309.020000                 4.000000          3.200000
# 50%                  1114.870000                17.000000          7.000000
# 75%                  3743.970000                43.000000         15.200000
# max                 20778.560000               348.000000         54.800000
#
#        %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# count     1000000.000000   1000000.000000    1000000.000000  1000000.000000
# mean           11.477500        40.064704         11.410470       40.164535
# std            11.240512        35.093804         11.159382       34.441304
# min             0.000000         0.000000          0.000000        0.000000
# 25%             0.000000         0.000000          0.000000        0.000000
# 50%            10.000000        46.000000         10.000000       48.000000
# 75%            20.000000        73.000000         20.000000       72.000000
# max            70.000000        97.000000         70.000000       96.000000
#
#        t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# count    1000000.000000         1000000.000000         1000000.000000  ...
# mean        9213.483187            7570.282545             767.744356  ...
# std         8707.447796            8643.360310             914.209913  ...
# min          366.000000               0.000000               0.000000  ...
# 25%         4387.000000            3096.000000               0.000000  ...
# 50%         6757.000000            5788.000000             403.000000  ...
# 75%        11184.000000            9233.000000            1316.000000  ...
# max        65655.000000           63880.000000            5037.000000  ...
#
#        antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# count             1000000.000000                 1000000.000000
# mean                   85.159235                    3261.933759
# std                    92.644842                    9388.895220
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.000000
# 50%                   103.000000                       0.000000
# 75%                   159.000000                       0.000000
# max                   342.000000                   60287.000000
#
#        antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# count                 1000000.000000           1000000.000000
# mean                       61.384065              3122.287067
# std                       186.508646              6964.412860
# min                         0.000000                16.000000
# 25%                         0.000000               202.200000
# 50%                         0.000000               856.300000
# 75%                         0.000000              2896.800000
# max                       938.000000             61995.600000
#
#        total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# count      1.000000e+06                1000000.000000           1.000000e+06
# mean       8.464317e+04                   2198.124722           5.989438e+04
# std        1.749394e+05                   5507.176326           1.412311e+05
# min        1.730000e+02                      0.000000           0.000000e+00
# 25%        5.006000e+03                    108.500000           2.535000e+03
# 50%        1.988100e+04                    442.400000           1.166600e+04
# 75%        8.413500e+04                   1531.900000           4.397700e+04
# max        1.349311e+06                  46450.500000           1.033967e+06
#
#        opioid_day_supply  opioid_prescriber_rate  is_excluded
# count     1000000.000000          1000000.000000    1000000.0
# mean         5612.499062                9.269286          1.0
# std         17120.622710               17.493630          0.0
# min             0.000000                0.000000          1.0
# 25%             0.000000                0.000000          1.0
# 50%             0.000000                0.000000          1.0
# 75%          2160.000000                7.970000          1.0
# max        125975.000000               75.000000          1.0
#
# [8 rows x 27 columns]

# %%
std = fudge.describe().loc["std"]
std = std[0:26]

# %%
rtstd = std.map(lambda x : math.sqrt(x)/2) #use half of square root of standard deviation as the range for gaussian normal
rtstd = rtstd.to_dict()

# %%
for key in rtstd:
    #fudge[key] = fudge[key].map(lambda x: (np.random.normal(x, rtstd[key])))
    fudge[key] = fudge[key].map(lambda x: (np.random.normal(x, 2)))
fudge = fudge[fudge>=0]
fudge.dropna(inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
rtstd
# Out:
# {'t_cost_per_claim_excluded': 30.778170068252898,
#  't_claim_count_schedule2': 3.6498902604944305,
#  't_claim_per_bene': 1.5642765237289618,
#  '%b2bg_claim_count': 1.6763436736130868,
#  '%b2bg_drug_cost': 2.9620011923203977,
#  '%b2t_claim_count': 1.6702830339870398,
#  '%b2t_drug_cost': 2.93433569885104,
#  't_cost_per_claim': 46.65685318358475,
#  't_cost_per_claim_ge65': 46.48483707035998,
#  't_claim_per_bene_ge65': 15.1179521803368,
#  'mapd_cost_per_claim': 41.8807428189209,
#  'pdp_cost_per_claim': 46.34801178212764,
#  'lis_cost_per_claim': 51.54887602049386,
#  'nonlis_cost_per_claim': 42.572142232027545,
#  'opioid_cost_per_claim': 43.49329897350196,
#  'opioid_claim_per_bene': 9.379110711241319,
#  'antibiotic_cost_per_claim': 50.46615800834265,
#  'antibiotic_claim_per_bene': 4.81260954258536,
#  'antipsych_cost_per_claim_ge65': 48.44815584810507,
#  'antipsych_claim_per_bene_ge65': 6.828408423877052,
#  'total_30_day_fill_count': 41.72652891210207,
#  'total_day_supply': 209.12876005838976,
#  'total_30_day_fill_count_ge65': 37.105175938925605,
#  'total_day_supply_ge65': 187.90366269566275,
#  'opioid_day_supply': 65.4228987250798,
#  'opioid_prescriber_rate': 2.0912693265830424}

# %%
fudge.describe()
# Out:
#        t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# count              112348.000000            112348.000000     112348.000000
# mean                 3841.899217               117.325454         19.774286
# std                  3071.086029                90.145643         11.934178
# min                    43.098160                 0.023874          0.001161
# 25%                  1687.013027                42.927253         11.270473
# 50%                  3244.584151                95.240380         17.720374
# 75%                  5070.220420               155.145396         27.176304
# max                 20785.155202               354.906284         61.432155
#
#        %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# count      112348.000000    112348.000000     112348.000000   112348.000000
# mean           19.101967        67.294155         18.514540       66.030818
# std             6.552653        16.431082          5.968937       15.376120
# min             0.001447         0.004608          0.002236        0.002655
# 25%            16.471087        61.024861         16.363710       61.031995
# 50%            19.665929        70.590837         19.493378       69.523273
# 75%            21.926333        75.913573         21.412330       74.088066
# max            45.142890       103.455344         45.222162      103.786995
#
#        t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# count     112348.000000          112348.000000          112348.000000  ...
# mean        9258.801994            9390.214125            1828.243105  ...
# std         8575.204238           11224.444252            1070.506715  ...
# min          527.739812               0.368613               0.000944  ...
# 25%         5638.450645            5306.369723            1094.431789  ...
# 50%         6322.838726            6014.412906            1597.072669  ...
# 75%        11279.442146           10200.861492            2568.485461  ...
# max        65660.363689           63887.474632            5045.676041  ...
#
#        antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# count              112348.000000                  112348.000000
# mean                  191.387227                    8999.439545
# std                    84.839580                   12816.931626
# min                     0.000111                       0.000015
# 25%                   144.602726                       2.338716
# 50%                   176.121755                    4720.690683
# 75%                   230.838567                   11349.443388
# max                   349.105266                   60290.583918
#
#        antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# count                  112348.000000            112348.000000
# mean                      246.501556             12302.373965
# std                       288.680388             14185.554910
# min                         0.000007                50.850292
# 25%                         1.231409              2466.861289
# 50%                         3.533027              5723.156944
# 75%                       497.536886             17848.726424
# max                       943.484218             62003.621018
#
#        total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# count      1.123480e+05                 112348.000000           1.123480e+05
# mean       3.253869e+05                   9520.273311           2.535337e+05
# std        3.454393e+05                  11260.887517           2.818986e+05
# min        3.791098e+02                      0.489928           5.836711e-03
# 25%        7.067262e+04                   1248.827667           3.471060e+04
# 50%        1.574876e+05                   4063.390500           1.125208e+05
# 75%        5.154908e+05                  14651.857536           4.249538e+05
# max        1.349318e+06                  46458.324053           1.033974e+06
#
#        opioid_day_supply  opioid_prescriber_rate  is_excluded
# count      112348.000000           112348.000000     112348.0
# mean        13706.564143                9.030412          1.0
# std         21500.865824               12.639421          0.0
# min             0.000368                0.000194          1.0
# 25%          1808.305494                3.003531          1.0
# 50%          5406.318788                5.584722          1.0
# 75%         13608.510057                9.279360          1.0
# max        125982.446426               80.411606          1.0
#
# [8 rows x 27 columns]

# %%
only_excluded.describe()
# Out:
#        t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# count                 151.000000               151.000000        151.000000
# mean                 2781.696026                35.860927         10.496026
# std                  3811.580951                53.328671          9.810966
# min                    19.460000                 1.000000          0.000000
# 25%                   313.405000                 4.000000          3.200000
# 50%                  1114.870000                17.000000          7.000000
# 75%                  3697.195000                43.000000         15.050000
# max                 20778.560000               348.000000         54.800000
#
#        %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# count         151.000000       151.000000        151.000000      151.000000
# mean           11.456954        40.000000         11.390728       40.105960
# std            11.278141        35.212119         11.197603       34.559929
# min             0.000000         0.000000          0.000000        0.000000
# 25%             0.000000         0.000000          0.000000        0.000000
# 50%            10.000000        46.000000         10.000000       48.000000
# 75%            20.000000        72.500000         20.000000       72.000000
# max            70.000000        97.000000         70.000000       96.000000
#
#        t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# count        151.000000             151.000000             151.000000  ...
# mean        9209.384106            7569.993377             765.741722  ...
# std         8733.751764            8657.575726             915.404919  ...
# min          366.000000               0.000000               0.000000  ...
# 25%         4403.500000            3116.500000               0.000000  ...
# 50%         6757.000000            5788.000000             403.000000  ...
# 75%        11131.000000            9180.500000            1295.500000  ...
# max        65655.000000           63880.000000            5037.000000  ...
#
#        antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# count                 151.000000                     151.000000
# mean                   85.105960                    3234.801325
# std                    92.888331                    9349.949227
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.000000
# 50%                   103.000000                       0.000000
# 75%                   157.500000                       0.000000
# max                   342.000000                   60287.000000
#
#        antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# count                     151.000000               151.000000
# mean                       61.245033              3111.717219
# std                       186.921194              6966.685606
# min                         0.000000                16.000000
# 25%                         0.000000               202.750000
# 50%                         0.000000               856.300000
# 75%                         0.000000              2888.900000
# max                       938.000000             61995.600000
#
#        total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# count      1.510000e+02                    151.000000           1.510000e+02
# mean       8.437911e+04                   2189.626490           5.967601e+04
# std        1.751018e+05                   5510.199486           1.413892e+05
# min        1.730000e+02                      0.000000           0.000000e+00
# 25%        5.105500e+03                    109.400000           2.553000e+03
# 50%        1.988100e+04                    442.400000           1.166600e+04
# 75%        8.326700e+04                   1519.400000           4.295400e+04
# max        1.349311e+06                  46450.500000           1.033967e+06
#
#        opioid_day_supply  opioid_prescriber_rate  is_excluded
# count         151.000000              151.000000        151.0
# mean         5627.443709                9.291854          1.0
# std         17221.508023               17.578962          0.0
# min             0.000000                0.000000          1.0
# 25%             0.000000                0.000000          1.0
# 50%             0.000000                0.000000          1.0
# 75%          2089.000000                7.870000          1.0
# max        125975.000000               75.000000          1.0
#
# [8 rows x 27 columns]

# %%
fudge.shape
# Out:
# (112348, 27)

# %%
fudge=fudge.sample(n=10000)
fudge.head()
# Out:
#         t_cost_per_claim_excluded  t_claim_count_schedule2  t_claim_per_bene  \
# 458103                4226.959824                40.647300         15.594521
# 796675                1062.277114                93.572026         14.579364
# 877052                1047.713752               100.318061         15.549482
# 253274                4623.943443               232.107391         25.013131
# 590027                4038.156056               240.089898         35.412059
#
#         %b2bg_claim_count  %b2bg_drug_cost  %b2t_claim_count  %b2t_drug_cost  \
# 458103          30.091031        62.438589         19.430269       60.278068
# 796675          21.382861        96.362672         19.477912       71.956961
# 877052           9.332288        48.676675         10.288515       49.708353
# 253274          19.474872        74.271641         18.935561       68.365476
# 590027          18.751156        70.808341         19.777285       74.133568
#
#         t_cost_per_claim  t_cost_per_claim_ge65  t_claim_per_bene_ge65  ...  \
# 458103      12414.376525           12707.227376            1422.943010  ...
# 796675       3566.534680            3858.647383            1598.283604  ...
# 877052       3851.720889            3810.665229            1586.710234  ...
# 253274       5855.708627            5630.477511            2666.494531  ...
# 590027       5863.428574            5561.348184            3167.968464  ...
#
#         antibiotic_claim_per_bene  antipsych_cost_per_claim_ge65  \
# 458103                 163.217900                   42211.784303
# 796675                 148.454907                   40590.412406
# 877052                 339.881287                    9153.001907
# 253274                 295.343043                   11352.761145
# 590027                 229.513122                    6016.324125
#
#         antipsych_claim_per_bene_ge65  total_30_day_fill_count  \
# 458103                     324.046336              2171.137203
# 796675                       0.233186              4996.893496
# 877052                     384.802634              4836.885874
# 253274                     565.218417             29051.313478
# 590027                     676.956415             25347.323984
#
#         total_day_supply  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# 458103      62876.266521                    993.714730           28867.979645
# 796675     141813.161797                   2473.801429           70762.144175
# 877052     110133.538096                   3801.751915           86502.698859
# 253274     767947.986299                  24784.631672          653583.438315
# 590027     722202.211742                  19292.348214          554114.825599
#
#         opioid_day_supply  opioid_prescriber_rate  is_excluded
# 458103        7532.838896                9.803811            1
# 796675        6662.173720                5.196749            1
# 877052        1809.220809                3.657128            1
# 253274       11594.399371                3.837689            1
# 590027       42343.420257                8.527136            1
#
# [5 rows x 27 columns]

# %%
ag_2016 = pd.concat([new_main_2016, fudge])
ag_2016.dropna(inplace=True)

# %%
ag_2016[ag_2016["is_excluded"]==1].shape
# Out:
# (10000, 27)

# %%
ag_2016.shape
# Out:
# (714070, 27)

# %% [markdown]
# #Applying PCA, 2 components and 3 components for variance visualization
#
# pca = decomposition.PCA(n_components='mle')
# pca.fit(part_d_df)
# npi_drug_df_transformed = pca.transform(part_d_df)
# plt.plot(np.cumsum(pca.explained_variance_ratio_), color='r')
#
# pca = decomposition.PCA(n_components='mle')
# pca.fit(part_d_df)
# npi_drug_cross_df_transformed = pca.transform(part_d_df)
# plt.plot(np.cumsum(pca.explained_variance_ratio_))
# plt.xlabel('number of components')
# plt.ylabel('cumulative explained variance')
#
# plt.vlines(1, color='grey', ymax=0.1, ymin=0, linestyle=':')
# plt.vlines(2, color='grey', ymax=0.1, ymin=0, linestyle=':')
#
# plt.annotate('1 components', xy=(0.6, 0.05), xytext=(0.9, 0.05), fontsize=15, rotation=90)
# plt.annotate('2 components', xy=(1.6, 0.05), xytext=(1.9, 0.05), fontsize=15, rotation=90)
#
# plt.savefig('VarExp.jpeg', dpi=1000)
# plt.tight_layout()
# plt.show()

# %%
#Training without Upsampling or Downsampling
#fudged data (ag_2016) only for train, regular data (new_df) only for test

X_train = ag_2016.drop(['is_excluded'], axis=1)
y_train = ag_2016['is_excluded']
X_test = new_df.drop(['is_excluded'], axis =1)
y_test = new_df["is_excluded"]
#X = new_main_2016.drop(['is_excluded'], axis=1)
#y = new_main_2016['is_excluded']
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
pca = decomposition.PCA(n_components='mle')
X_train = pca.fit_transform(X_train)
X_test = pca.fit_transform(X_test)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [7.45750919e-01 1.86375752e-01 2.38513194e-02 1.35848357e-02
#  8.70628365e-03 6.18692720e-03 6.05737012e-03 5.27128148e-03
#  1.61199324e-03 1.07093729e-03 8.08092011e-04 4.35531772e-04
#  2.73809989e-04 9.66599965e-06 4.44606380e-06 3.48314300e-07
#  2.52503010e-07 1.11792618e-07 5.76736327e-08 5.10896020e-08
#  6.47338194e-09 3.03945822e-09 2.75420901e-09 2.47562526e-10
#  1.60472932e-10]

# %%
Labels = ag_2016.drop(["is_excluded"],axis = 1).columns

# %%
#new Labels after PCA
most_important = [np.abs(pca.components_[i]).argmax() for i in range(len(pca.components_))]
most_important_names = [Labels[most_important[i]] for i in range(len(pca.components_))]
dic = {'PC{}'.format(i+1): most_important_names[i] for i in range(len(pca.components_))}
newLabels = list(dic.values())
newLabels
# Out:
# ['total_day_supply',
#  't_cost_per_claim',
#  'mapd_cost_per_claim',
#  'lis_cost_per_claim',
#  'mapd_cost_per_claim',
#  'pdp_cost_per_claim',
#  'total_day_supply_ge65',
#  'nonlis_cost_per_claim',
#  'antibiotic_cost_per_claim',
#  'opioid_day_supply',
#  'antipsych_cost_per_claim_ge65',
#  't_cost_per_claim_excluded',
#  'opioid_cost_per_claim',
#  'total_30_day_fill_count',
#  't_claim_per_bene_ge65',
#  'opioid_claim_per_bene',
#  'antipsych_claim_per_bene_ge65',
#  'antibiotic_claim_per_bene',
#  'total_30_day_fill_count_ge65',
#  '%b2bg_drug_cost',
#  'opioid_prescriber_rate',
#  '%b2bg_claim_count',
#  't_claim_count_schedule2',
#  't_claim_per_bene',
#  '%b2t_drug_cost']

# %%
clf = RandomForestClassifier(n_estimators=25)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=25, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
#excluded samples in test data
count = 0
for x in y_test:
    if int(x)== 1:
        count +=1
print(count)
# Out:
# 151

# %%
#excluded samples in train data
count2 = 0
for x in y_train:
    if int(x)== 1:
        count2 +=1
print(count2)
# Out:
# 10000

# %%
clf.feature_importances_
# Out:
# array([0.06334776, 0.03336349, 0.02538915, 0.03116867, 0.0230443 ,
#        0.04572657, 0.03011468, 0.03336944, 0.02393744, 0.0608663 ,
#        0.0542831 , 0.03572179, 0.05155753, 0.05529869, 0.04001906,
#        0.04031975, 0.02419872, 0.03434862, 0.0261825 , 0.02642488,
#        0.01673339, 0.01760939, 0.01805923, 0.00760428, 0.18131129])

# %% [markdown]
# coef_df = pd.DataFrame(clf.feature_importances_, Labels, columns = ["Importances"])
# coef_df.sort_values("Importances", ascending = False)

# %% [markdown]
# check for contamination by not dropping the npis and seeing if any of them overlap between training and testing
# train_nps = set(X_train['npi'])
# test_nps = set(X_test['npi'])
# print(len(train_nps.intersection(test_nps))) # should be zero

# %%
y_pred = clf.predict(X_train)
y_pred_prob = clf.predict_proba(X_train)
print(y_pred_prob)
print(roc_auc_score(y_train, y_pred_prob[:,1]))
confusion_matrix(y_train, y_pred)
# Out:
# [[1.   0.  ]
#  [1.   0.  ]
#  [1.   0.  ]
#  ...
#  [0.08 0.92]
#  [0.   1.  ]
#  [0.   1.  ]]
# 1.0
# array([[704070,      0],
#        [     4,   9996]], dtype=int64)

# %%
y_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
print(y_pred_prob)
print(roc_auc_score(y_test, y_pred_prob[:,1]))
confusion_matrix(y_test, y_pred)
# Out:
# [[1.   0.  ]
#  [1.   0.  ]
#  [0.96 0.04]
#  ...
#  [1.   0.  ]
#  [1.   0.  ]
#  [1.   0.  ]]
# 0.5445173103982814
# array([[175865,      2],
#        [   151,      0]], dtype=int64)

# %%
#Upsampling only

ag_2016_majority = ag_2016[ag_2016['is_excluded'] == 0]
ag_2016_minority = ag_2016[ag_2016['is_excluded'] > 0]

# Increase by 10 times
ag_2016_minority_upsampled = resample(ag_2016_minority, replace=True, n_samples=100000, random_state=42) 
ag_2016_upsampled = pd.concat([ag_2016_majority, ag_2016_minority_upsampled])  
ag_2016_upsampled['is_excluded'].value_counts()
# Out:
# 0    704070
# 1    100000
# Name: is_excluded, dtype: int64

# %%
#fudged data (ag_2016) only for train, regular data (new_df) only for test
X_train = ag_2016_upsampled.drop(['is_excluded'], axis=1)
y_train = ag_2016_upsampled['is_excluded']
X_test = new_df.drop(['is_excluded'], axis =1)
y_test = new_df["is_excluded"]

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
pca = decomposition.PCA(n_components='mle')
X_train = pca.fit_transform(X_train)
X_test = pca.fit_transform(X_test)

# %%
clf = RandomForestClassifier(n_estimators=25, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=25, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
y_pred = clf.predict(X_train)
y_pred_prob = clf.predict_proba(X_train)
print(roc_auc_score(y_train, y_pred_prob[:,1]))
confusion_matrix(y_train, y_pred)
# Out:
# 1.0
# array([[704070,      0],
#        [     0, 100000]], dtype=int64)

# %%
y_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
print(roc_auc_score(y_test, y_pred_prob[:,1]))
confusion_matrix(y_test, y_pred)
# Out:
# 0.5035889553352648
# array([[175867,      0],
#        [   151,      0]], dtype=int64)

# %%
#Training on downsampled only and testing on regular

ag_2016_majority = ag_2016[ag_2016['is_excluded'] == 0]
ag_2016_minority = ag_2016[ag_2016['is_excluded'] > 0]

# Reduce by 10 times
ag_2016_majority_downsampled = resample(ag_2016_majority, replace=True, n_samples=81980, random_state=42) 
ag_2016_downsampled = pd.concat([ag_2016_majority_downsampled, ag_2016_minority]) 
ag_2016_downsampled['is_excluded'].value_counts()
# Out:
# 0    81980
# 1    10000
# Name: is_excluded, dtype: int64

# %%
#fudged data (ag_2016) only for train, regular data (new_df) only for test
X_train = ag_2016_downsampled.drop(['is_excluded'], axis=1)
y_train = ag_2016_downsampled['is_excluded']
X_test = new_df.drop(['is_excluded'], axis =1)
y_test = new_df["is_excluded"]

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
pca = decomposition.PCA(n_components='mle')
X_train = pca.fit_transform(X_train)
X_test = pca.fit_transform(X_test)

# %%
clf = RandomForestClassifier(n_estimators=25, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=25, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
y_pred = clf.predict(X_train)
y_pred_prob = clf.predict_proba(X_train)
print(roc_auc_score(y_train, y_pred_prob[:,1]))
confusion_matrix(y_train, y_pred)
# Out:
# 1.0
# array([[81980,     0],
#        [    1,  9999]], dtype=int64)

# %%
y_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
print(roc_auc_score(y_test, y_pred_prob[:,1]))
confusion_matrix(y_test, y_pred)
# Out:
# 0.5368686948373879
# array([[175865,      2],
#        [   151,      0]], dtype=int64)

# %%
#Upsampling/downsampling on training and testing on regular

ag_2016_majority = ag_2016[ag_2016['is_excluded'] == 0]
ag_2016_minority = ag_2016[ag_2016['is_excluded'] > 0]

ag_2016_updownsampled = pd.concat([ag_2016_majority_downsampled, ag_2016_minority_upsampled]) 
ag_2016_updownsampled['is_excluded'].value_counts()
# Out:
# 1    100000
# 0     81980
# Name: is_excluded, dtype: int64

# %%
#fudged data (ag_2016) only for train, regular data (new_df) only for test

X_train = ag_2016_updownsampled.drop(['is_excluded'], axis=1)
y_train = ag_2016_updownsampled['is_excluded']
X_test = new_df.drop(['is_excluded'], axis =1)
y_test = new_df["is_excluded"]
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
pca = decomposition.PCA(n_components='mle')
X_train = pca.fit_transform(X_train)
X_test = pca.fit_transform(X_test)

# %%
clf = RandomForestClassifier(n_estimators=25, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=25, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
y_pred = clf.predict(X_train)
y_pred_prob = clf.predict_proba(X_train)
print(roc_auc_score(y_train, y_pred_prob[:,1]))
confusion_matrix(y_train, y_pred)
# Out:
# 1.0
# array([[ 81980,      0],
#        [     0, 100000]], dtype=int64)

# %%
y_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)
print(roc_auc_score(y_test, y_pred_prob[:,1]))
confusion_matrix(y_test, y_pred)
# Out:
# 0.5353088729716996
# array([[175867,      0],
#        [   151,      0]], dtype=int64)

# %% [markdown]
# In conclusion, results from downsampling is the best.

# %%
#Classification Model Comparisons

def warn(*args, **kwargs):
    pass

import warnings
warnings.warn = warn

from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import cross_validate, GridSearchCV, StratifiedKFold
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, auc, recall_score, precision_score, accuracy_score, f1_score

seed = 42

# %% [markdown]
# #Identifying the best model algorithm
# colors = ["#08306b", "#08519c", "#1361a9", "#4292c6", "#6baed6", 'rgb(76,000,153)', 'rgb(153,000,153)']
#
# scoring = {'AUC': 'roc_auc', 'Accuracy': 'accuracy', 'F1': 'f1'}
#
# names = ["Naive Bayes", "Nearest Neighbors", "RBF SVM",
#          "AdaBoost", "GradientBoost", "ExtraTrees", "Random Forest"]
#
# classifiers = [
#             GaussianNB(),
#             KNeighborsClassifier(n_neighbors=5),
#             SVC(kernel="rbf", C=1, probability=True),
#             AdaBoostClassifier(n_estimators=25, random_state=seed),
#             GradientBoostingClassifier(n_estimators=1000, random_state=seed),
#             ExtraTreesClassifier(n_estimators=25, random_state=seed),
#             RandomForestClassifier(n_estimators=25, random_state=seed),]
#
# trace_dict = {'x_vals':[], 'y_vals':[], 'y_error':[], 'colors':[], 'names':[]}
#
# #iterate over classifiers
# counter = 0
# for color, name, clf in tqdm_notebook(zip(colors, names, classifiers), total=len(names)):
#     cv_results = cross_validate(clf, X, y, scoring=scoring, cv=5, return_train_score=True)
#     print('########################### \nFor {}'.format(name))
#     for score in scoring:
#         print('{0:s}: Mean-{1:.4f}  STD-{2:.4f}'.format(score, cv_results['test_'+score].mean(),\
#                                                         cv_results['test_'+score].std()))
#
#     trace_dict['x_vals'].append(counter)
#     counter += 1
#     trace_dict['y_vals'].append(cv_results['test_F1'].mean())
#     trace_dict['y_error'].append()
#     trace_dict['colors'].append(color)
#     trace_dict['names'].append(name)
#     trace_dict['y_error'].append(np.std(cv_results['test_F1']))

# %%
# Identifying the best model algorithm
colors = ["#08306b", "#08519c", "#1361a9", "#4292c6", "#6baed6", 'rgb(76,000,153)', 'rgb(153,000,153)']

names = ["GradientBoost", "ExtraTrees", "Random Forest", "Naive Bayes", "Nearest Neighbors", "AdaBoost"]

classifiers = [
            GradientBoostingClassifier(n_estimators=50, random_state=seed),
            ExtraTreesClassifier(n_estimators=25, random_state=seed),
            RandomForestClassifier(n_estimators=25, random_state=seed),      
            GaussianNB(),
            KNeighborsClassifier(n_neighbors=5),
            AdaBoostClassifier(n_estimators=25, random_state=seed)]

# %%
trace_dict = {'x_vals':[], 'y_vals':[], 'colors':[], 'names':[]}
                                                                                         
# iterate over classifiers
counter = 0
for color, name, clf in tqdm_notebook(zip(colors, names, classifiers), total=len(names)):
    X_train = ag_2016.drop(['is_excluded'], axis=1)
    y_train = ag_2016['is_excluded']
    X_test = new_df.drop(['is_excluded'], axis =1)
    y_test = new_df["is_excluded"]
    clf.fit(X_train, y_train)
    y_pred_prob = clf.predict_proba(X_test)
    cv_results = roc_auc_score(y_test, y_pred_prob[:,1])
    print('########################### \nFor {}'.format(name))
              
    trace_dict['x_vals'].append(counter)
    counter += 1
    print(cv_results)
    trace_dict['y_vals'].append(cv_results.mean())
    trace_dict['colors'].append(color)
    trace_dict['names'].append(name)
# Out:
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# ###########################
# For GradientBoost
# 0.6052828452506459
# ###########################
# For ExtraTrees
# 0.7701043612992163
# ###########################
# For Random Forest
# 0.6219271961122638
# ###########################
# For Naive Bayes
# 0.5961691701325923
# ###########################
# For Nearest Neighbors
# 0.844197660355694
# ###########################
# For AdaBoost
# 0.47386968410844177

# %%
# Plotting ROC curves of the models
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
import plotly

n_classes = 1
fpr = dict()
tpr = dict()
roc_auc = dict()
plt.figure()
lw = 2
trace_dict = {}

for color, name, clf in tqdm_notebook(zip(colors, names, classifiers), total=len(names)):
    y_score = clf.fit(X_train, y_train).predict_proba(X_test)
    fpr[name], tpr[name], _ = roc_curve(y_test[:], y_score[:, 1])
    roc_auc[name] = auc(fpr[name], tpr[name])
    trace_dict.update({'trace' + name: go.Scatter(x=fpr[name], y=tpr[name], mode='lines', 
                                       line=dict(color=color, width=lw),
                                       showlegend=True,
                                       name='{0:s} AUC: {1:.2f}'.format(name, roc_auc[name]))})
trace_guess = go.Scatter(x=[0, 1], y=[0, 1], 
                mode='lines', 
                line=dict(color='navy', width=lw, dash='dash'),
                showlegend=False)
data = [trace_dict[trace] for trace in trace_dict] + [trace_guess]
layout = go.Layout(title='Receiver Operating Characteristics',
                   xaxis=dict(title='False Positive Rate'),
                   yaxis=dict(title='True Positive Rate'),
                   margin=go.Margin(l=50, r=50, b=30, t=65, pad=4),
                   legend=dict(x=0.7, y=0.4, font=dict(size=18))
                  )
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='ROCs')
# Out:
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~acopolu/15.embed" height="525px" width="100%"></iframe>
